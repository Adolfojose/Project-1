# %% [markdown]
# # Heart Disease: EDA

# %%
# Dependencies and Setup
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import scipy.stats as stats

# %%
# Files to load
heart_data_to_load = r"C:\Users\RyanF\Documents\Bootcamp Challenges\Project-1\Resources\heart.csv"
heart_predict_to_load = r"C:\Users\RyanF\Documents\Bootcamp Challenges\Project-1\Resources\Heart_Disease_Prediction.csv"

# %%
# assign heart_data DataFrame
heart_data_df = pd.DataFrame(heart_data)

# assign heart_predict dataframe

heart_predict_df = pd.DataFrame(heart_predict)

# %%
#disply heart_data DataFrame
heart_data_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
#disply heart_predict DataFrame
heart_predict_df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %% [markdown]
# # Clean Data

# %%
# replace Heart Disease w/ 1 & 0

test = heart_predict_df

test = test.replace({'Heart Disease': 'Presence'},1)
test = test.replace({'Heart Disease': 'Absence'},0)
test
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium  Heart Disease
# 0                          3         3              1
# 1                          0         7              0
# 2                          0         7              1
# 3                          1         7              0
# 4                          1         3              0
# ..                       ...       ...            ...
# 265                        0         7              0
# 266                        0         7              0
# 267                        0         3              0
# 268                        0         6              0
# 269                        3         3              1
#
# [270 rows x 14 columns]

# %%
# columns
print(heart_predict.columns
     )
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
#disply heart_data_df
heart_data_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
heart_data_df_cc = heart_data_df.rename(columns={"age": "Age",
                                              "sex": "Sex",                                               
                                              "cp": "Chest pain type",
                                              "trestbps": "BP",   
                                              "chol": "Cholesterol",
                                              "fbs": "FBS over 120",
                                             "exang": "Exercise angina",
                                                "ca": "Number of vessels fluro",
                                                "target": "Heart Disease"})
#disply
heart_data_df_cc
# Out:
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  restecg  \
# 0      52    1                0  125          212             0        1
# 1      53    1                0  140          203             1        0
# 2      70    1                0  145          174             0        1
# 3      61    1                0  148          203             0        1
# 4      62    0                0  138          294             1        1
# ...   ...  ...              ...  ...          ...           ...      ...
# 1020   59    1                1  140          221             0        1
# 1021   60    1                0  125          258             0        0
# 1022   47    1                0  110          275             0        0
# 1023   50    0                0  110          254             0        0
# 1024   54    1                0  120          188             0        1
#
#       thalach  Exercise angina  oldpeak  slope  Number of vessels fluro  thal  \
# 0         168                0      1.0      2                        2     3
# 1         155                1      3.1      0                        0     3
# 2         125                1      2.6      0                        0     3
# 3         161                0      0.0      2                        1     3
# 4         106                0      1.9      1                        3     2
# ...       ...              ...      ...    ...                      ...   ...
# 1020      164                1      0.0      2                        0     2
# 1021      141                1      2.8      1                        1     3
# 1022      118                1      1.0      1                        1     2
# 1023      159                0      0.0      2                        0     2
# 1024      113                0      1.4      1                        1     3
#
#       Heart Disease
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1020              1
# 1021              0
# 1022              0
# 1023              1
# 1024              0
#
# [1025 rows x 14 columns]

# %%
# merge heart data w/ corrected columns with heart predict dataframe
heart_data_merge = pd.merge(test, heart_data_df_cc, how="outer", on=['Age', 
                                                                                 "Sex",
                                                                                 "Chest pain type",
                                                                                 "BP",
                                                                                 "Cholesterol",
                                                                                 "FBS over 120",
                                                                                 "Exercise angina",
                                                                                "Number of vessels fluro",
                                                                                 "Heart Disease"
                                                                                ])

# display
heart_data_merge
# Out:
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0      70    1                4  130          322             0          2.0
# 1      67    0                3  115          564             0          2.0
# 2      57    1                2  124          261             0          0.0
# 3      64    1                4  128          263             0          0.0
# 4      74    0                2  120          269             0          2.0
# ...   ...  ...              ...  ...          ...           ...          ...
# 1290   59    1                3  160          273             0          NaN
# 1291   59    1                3  160          273             0          NaN
# 1292   54    1                0  120          188             0          NaN
# 1293   54    1                0  120          188             0          NaN
# 1294   54    1                0  120          188             0          NaN
#
#       Max HR  Exercise angina  ST depression  Slope of ST  \
# 0      109.0                0            2.4          2.0
# 1      160.0                0            1.6          2.0
# 2      141.0                0            0.3          1.0
# 3      105.0                1            0.2          2.0
# 4      121.0                1            0.2          1.0
# ...      ...              ...            ...          ...
# 1290     NaN                0            NaN          NaN
# 1291     NaN                0            NaN          NaN
# 1292     NaN                0            NaN          NaN
# 1293     NaN                0            NaN          NaN
# 1294     NaN                0            NaN          NaN
#
#       Number of vessels fluro  Thallium  Heart Disease  restecg  thalach  \
# 0                           3       3.0              1      NaN      NaN
# 1                           0       7.0              0      NaN      NaN
# 2                           0       7.0              1      NaN      NaN
# 3                           1       7.0              0      NaN      NaN
# 4                           1       3.0              0      NaN      NaN
# ...                       ...       ...            ...      ...      ...
# 1290                        0       NaN              0      0.0    125.0
# 1291                        0       NaN              0      0.0    125.0
# 1292                        1       NaN              0      1.0    113.0
# 1293                        1       NaN              0      1.0    113.0
# 1294                        1       NaN              0      1.0    113.0
#
#       oldpeak  slope  thal
# 0         NaN    NaN   NaN
# 1         NaN    NaN   NaN
# 2         NaN    NaN   NaN
# 3         NaN    NaN   NaN
# 4         NaN    NaN   NaN
# ...       ...    ...   ...
# 1290      0.0    2.0   2.0
# 1291      0.0    2.0   2.0
# 1292      1.4    1.0   3.0
# 1293      1.4    1.0   3.0
# 1294      1.4    1.0   3.0
#
# [1295 rows x 19 columns]

# %%
# checking for NaN values in merge dataframe
nan_columns = heart_data_merge.isna().any()
print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# Age                        False
# Sex                        False
# Chest pain type            False
# BP                         False
# Cholesterol                False
# FBS over 120               False
# EKG results                 True
# Max HR                      True
# Exercise angina            False
# ST depression               True
# Slope of ST                 True
# Number of vessels fluro    False
# Thallium                    True
# Heart Disease              False
# restecg                     True
# thalach                     True
# oldpeak                     True
# slope                       True
# thal                        True
# dtype: bool

# %%
# removing NaN columns from dataframe
heart_data_dn = heart_data_merge.dropna(axis=1)

# disply data w/o NaN
heart_data_dn
# Out:
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0      70    1                4  130          322             0
# 1      67    0                3  115          564             0
# 2      57    1                2  124          261             0
# 3      64    1                4  128          263             0
# 4      74    0                2  120          269             0
# ...   ...  ...              ...  ...          ...           ...
# 1290   59    1                3  160          273             0
# 1291   59    1                3  160          273             0
# 1292   54    1                0  120          188             0
# 1293   54    1                0  120          188             0
# 1294   54    1                0  120          188             0
#
#       Exercise angina  Number of vessels fluro  Heart Disease
# 0                   0                        3              1
# 1                   0                        0              0
# 2                   0                        0              1
# 3                   1                        1              0
# 4                   1                        1              0
# ...               ...                      ...            ...
# 1290                0                        0              0
# 1291                0                        0              0
# 1292                0                        1              0
# 1293                0                        1              0
# 1294                0                        1              0
#
# [1295 rows x 9 columns]

# %%
# Check for duplicate rows
duplicate_rows = heart_data_dn.duplicated()

# Print the duplicate rows
print(duplicate_rows)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1290     True
# 1291     True
# 1292    False
# 1293     True
# 1294     True
# Length: 1295, dtype: bool

# %%
# drop duplicate rows
heart_data_clean = heart_data_dn.drop_duplicates()

# disply df
heart_data_clean
# Out:
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0      70    1                4  130          322             0
# 1      67    0                3  115          564             0
# 2      57    1                2  124          261             0
# 3      64    1                4  128          263             0
# 4      74    0                2  120          269             0
# ...   ...  ...              ...  ...          ...           ...
# 1280   68    0                2  120          211             0
# 1283   44    0                2  108          141             0
# 1286   52    1                0  128          255             0
# 1289   59    1                3  160          273             0
# 1292   54    1                0  120          188             0
#
#       Exercise angina  Number of vessels fluro  Heart Disease
# 0                   0                        3              1
# 1                   0                        0              0
# 2                   0                        0              1
# 3                   1                        1              0
# 4                   1                        1              0
# ...               ...                      ...            ...
# 1280                0                        0              1
# 1283                0                        0              1
# 1286                1                        1              0
# 1289                0                        0              0
# 1292                0                        1              0
#
# [572 rows x 9 columns]

# %% [markdown]
# # EDA Stats & Data Visualizations

# %%
heart_data_clean.describe(include = 'all')
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  572.000000  572.000000       572.000000  572.000000   572.000000
# mean    54.426573    0.680070         2.006993  131.480769   247.991259
# std      9.068905    0.466857         1.485465   17.689717    51.700555
# min     29.000000    0.000000         0.000000   94.000000   126.000000
# 25%     48.000000    0.000000         0.750000  120.000000   212.000000
# 50%     55.000000    1.000000         2.000000  130.000000   243.000000
# 75%     61.000000    1.000000         3.000000  140.000000   276.250000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  Exercise angina  Number of vessels fluro  Heart Disease
# count    572.000000       572.000000               572.000000     572.000000
# mean       0.148601         0.328671                 0.695804       0.496503
# std        0.356006         0.470141                 0.977030       0.500425
# min        0.000000         0.000000                 0.000000       0.000000
# 25%        0.000000         0.000000                 0.000000       0.000000
# 50%        0.000000         0.000000                 0.000000       0.000000
# 75%        0.000000         1.000000                 1.000000       1.000000
# max        1.000000         1.000000                 4.000000       1.000000

# %%
#Disply Histogram of each column

# Age Hist.
plt.hist(heart_data_clean['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Heart Disease')
plt.xticks(range(20, 90, 10))  # Add x-axis ticks at 20, 30, 40, ..., 80
plt.yticks(range(0, 180, 20))  # Add y-axis ticks at 0, 20, 40, ..., 160
plt.show()


#Sex Histogram
plt.hist(heart_data_clean['Sex'], bins=2)
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.title('Sex Distribution of Heart Disease')
plt.show()

# Chest pain type Histogram
plt.hist(heart_data_clean['Chest pain type'], bins=4)
plt.xlabel('Chest pain type')
plt.ylabel('Frequency')
plt.title('Chest pain type Distribution of Heart Disease')
plt.show()


plt.hist(heart_data_clean['BP'], bins=10)
plt.xlabel('BP')
plt.ylabel('Frequency')
plt.title('BP Distribution of Heart Disease')
plt.show()


plt.hist(heart_data_clean['Cholesterol'], bins=5)
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
plt.title('Cholesterol Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['FBS over 120'], bins=2)
plt.xlabel('FBS over 120')
plt.ylabel('Frequency')
plt.title('FBS over 120 Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['Exercise angina'], bins=2)
plt.xlabel('Exercise angina')
plt.ylabel('Frequency')
plt.title('Exercise angina Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['Number of vessels fluro'], bins=5)
plt.xlabel('Number of vessels fluro')
plt.ylabel('Frequency')
plt.title('Number of vessels fluro Distribution of Heart Disease Dataset')
plt.show()

# %%
# Correlation matrix
correlation_matrix = heart_data_clean.corr()

plt.figure(figsize= (12, 8))

# Heatmap of correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='Spectral')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Pair plot
sns.pairplot(heart_data_clean)
plt.title('Pair Plot')
plt.show()

# %%
Focal_group = heart_data_clean.loc[(heart_data_clean['age'] >= 45) & (heart_data_clean['age'] <= 65)]

Focal_group
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# 5     58    0   0       100   248    0        0      122      0      1.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 719   52    1   0       108   233    1        1      147      0      0.1
# 720   64    1   2       140   335    0        1      158      0      0.0
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# 3        2   1     3       0
# 4        1   3     2       0
# 5        1   0     2       1
# ..     ...  ..   ...     ...
# 719      2   3     3       1
# 720      2   0     2       0
# 739      2   1     3       0
# 843      2   0     2       0
# 878      1   1     3       0
#
# [214 rows x 14 columns]
