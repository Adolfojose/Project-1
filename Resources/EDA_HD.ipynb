# %%
# Dependencies and Setup
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import scipy.stats as stats

# %%
# Files to load
heart_data_to_load = r"C:\Users\RyanF\Documents\Bootcamp Challenges\Project-1\Resources\heart.csv"
heart_predict_to_load = r"C:\Users\RyanF\Documents\Bootcamp Challenges\Project-1\Resources\Heart_Disease_Prediction.csv"

# %%
# read heart and heart disease prediction csv
heart_data = pd.read_csv(heart_data_to_load)

# %%
# assign heart_data DataFrame
heart_data_df = pd.DataFrame(heart_data)

# %%
#disply heart_data DataFrame
heart_data_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
#disply heart_data_df
heart_data_df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
# checking for NaN values in merge dataframe
nan_columns = heart_data_df.isna().any()
print("Columns with NaN values:")
print(nan_columns)
# Out:
# Columns with NaN values:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
# Check for duplicate rows
duplicate_rows = heart_data_df.duplicated()

# number of duplicate rows
num_duplicates = heart_data_df.duplicated().sum()

print(f"Number of duplicate rows: {num_duplicates}")

# Print the duplicate rows
print(duplicate_rows)
# Out:
# Number of duplicate rows: 723
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1025, dtype: bool

# %%
# drop duplicate rows
heart_data_clean = heart_data_df.drop_duplicates()

# disply df
heart_data_clean
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# 2        0   0     3       0
# 3        2   1     3       0
# 4        1   3     2       0
# ..     ...  ..   ...     ...
# 723      1   0     2       1
# 733      1   0     2       1
# 739      2   1     3       0
# 843      2   0     2       0
# 878      1   1     3       0
#
# [302 rows x 14 columns]

# %%
heart_data_clean.describe(include = 'all')
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
#Disply Histogram of each column

# Age Hist.
plt.hist(heart_data_clean['age'], bins=10)
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Age Distribution of Heart Disease')
plt.xticks(range(20, 90, 10))  # Add x-axis ticks at 20, 30, 40, ..., 80
plt.yticks(range(0, 180, 20))  # Add y-axis ticks at 0, 20, 40, ..., 160
plt.show()


#Sex Histogram
plt.hist(heart_data_clean['sex'], bins=2)
plt.xlabel('sex')
plt.ylabel('Frequency')
plt.title('Sex Distribution of Heart Disease')
plt.show()

# Chest pain type Histogram
plt.hist(heart_data_clean['cp'], bins=4)
plt.xlabel('Chest pain type')
plt.ylabel('Frequency')
plt.title('Chest pain type Distribution of Heart Disease')
plt.show()


plt.hist(heart_data_clean['trestbps'], bins=10)
plt.xlabel('trestbps')
plt.ylabel('Frequency')
plt.title('BP Distribution of Heart Disease')
plt.show()


plt.hist(heart_data_clean['chol'], bins=5)
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
plt.title('Cholesterol Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['fbs'], bins=2)
plt.xlabel('FBS over 120')
plt.ylabel('Frequency')
plt.title('FBS over 120 Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['exang'], bins=2)
plt.xlabel('Exercise angina')
plt.ylabel('Frequency')
plt.title('Exercise angina Distribution of Heart Disease Dataset')
plt.show()


plt.hist(heart_data_clean['ca'], bins=5)
plt.xlabel('Number of vessels fluro')
plt.ylabel('Frequency')
plt.title('Number of vessels fluro Distribution of Heart Disease Dataset')
plt.show()

# %%
# Correlation matrix
correlation_matrix = heart_data_clean.corr()

plt.figure(figsize= (12, 8))

# Heatmap of correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='Spectral')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Pair plot
sns.pairplot(heart_data_clean)
plt.title('Pair Plot')
plt.show()

# %%
Focal_group = heart_data_clean.loc[(heart_data_clean['age'] >= 45) & (heart_data_clean['age'] <= 65)]

Focal_group
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# 5     58    0   0       100   248    0        0      122      0      1.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 719   52    1   0       108   233    1        1      147      0      0.1
# 720   64    1   2       140   335    0        1      158      0      0.0
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# 3        2   1     3       0
# 4        1   3     2       0
# 5        1   0     2       1
# ..     ...  ..   ...     ...
# 719      2   3     3       1
# 720      2   0     2       0
# 739      2   1     3       0
# 843      2   0     2       0
# 878      1   1     3       0
#
# [214 rows x 14 columns]

# %%
# Correlation matrix
correlation_matrix = Focal_group.corr()

plt.figure(figsize= (12, 8))

# Heatmap of correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='Spectral')
plt.title('Correlation Heatmap: Focal Group 45-65')
plt.show()

# %%
import scipy.stats as stats

# Create the age groups
age_less_than_45 = heart_data_clean[heart_data_clean['age'] < 45]['age']
age_45_to_65 = heart_data_clean[(heart_data_clean['age'] >= 45) & (heart_data_clean['age'] <= 65)]['age']
age_above_65 = heart_data_clean[heart_data_clean['age'] > 65]['age']

# Perform the ANOVA test
f_statistic, p_value = stats.f_oneway(age_less_than_45, age_45_to_65, age_above_65)

# Print the results
print("ANOVA Test Results:")
print("F-statistic:", f_statistic)
print("p-value:", p_value)
# Out:
# ANOVA Test Results:
# F-statistic: 360.8577344602537
# p-value: 1.9124519004947764e-80

# %%
# Select the data for age groups 45 and 65
age_45 = heart_data_clean[heart_data_clean['age'] == 45]
age_65 = heart_data_clean[heart_data_clean['age'] == 65]
other_age = heart_data_clean[(heart_data_clean['age'] != 45) & (heart_data_clean['age'] != 65)]

# Perform t-test for age 45 vs. other age groups
t_statistic_45, p_value_45 = stats.ttest_ind(age_45['target'], other_age['target'])

# Perform t-test for age 65 vs. other age groups
t_statistic_65, p_value_65 = stats.ttest_ind(age_65['target'], other_age['target'])

# Print the results
print("T-test results for age 45 vs. other age groups:")
print("T-statistic:", t_statistic_45)
print("p-value:", p_value_45)
print()
print("T-test results for age 65 vs. other age groups:")
print("T-statistic:", t_statistic_65)
print("p-value:", p_value_65)
# Out:
# T-test results for age 45 vs. other age groups:
# T-statistic: 1.183684160164424
# p-value: 0.23750082650481782
#
# T-test results for age 65 vs. other age groups:
# T-statistic: -0.21447777524933437
# p-value: 0.830324199167341

# %%
# Select the data for age group 45-65
age_45_65 = heart_data_clean[(heart_data_clean['Age'] >= 45) & (heart_data_clean['Age'] <= 65)]

# Select the data for other age groups
other_age = heart_data_clean[(heart_data_clean['Age'] < 45) | (heart_data_clean['Age'] > 65)]

# Perform t-test for age group 45-65 vs. other age groups
t_statistic, p_value = stats.ttest_ind(age_45_65['target'], other_age['target'])

# Print the results
print("T-test results for age group 45-65 vs. other age groups:")
print("T-statistic:", t_statistic)
print("p-value:", p_value)
# Out:
# T-test results for age group 45-65 vs. other age groups:
# T-statistic: -2.6167725355462164
# p-value: 0.009326206053936853
